# %%
import pandas as pd

# %%
dataset=pd.read_csv("solar_panel_classification_data.csv")
dataset
# Out:
#        Panel  Efficiency  Degradation  Power(W)  solar_irradiance  \
# 0    Panel_C       10.50         0.26       276        234.582148
# 1    Panel_C       13.35         0.95       248        701.541503
# 2    Panel_A       11.59         0.67       248        800.323062
# 3    Panel_B       14.53         0.48       384        264.976616
# 4    Panel_C       12.29         0.22       299        314.577546
# ..       ...         ...          ...       ...               ...
# 995  Panel_B       18.10         0.15       302        714.936187
# 996  Panel_B       12.30         0.65       226        736.401113
# 997  Panel_C       10.12         0.56       291        863.499489
# 998  Panel_B       13.77         0.28       315        738.160525
# 999  Panel_A       15.27         0.38       210        316.168286
#
#      temperature   humidity  wind_speed  cloud_cover  panel_age  \
# 0      27.409992  34.203594   12.909419    47.135301          8
# ...

# %%
dataset.isnull().sum()
# Out:
# Panel               0
# Efficiency          0
# Degradation         0
# Power(W)            0
# solar_irradiance    0
# temperature         0
# humidity            0
# wind_speed          0
# cloud_cover         0
# panel_age           0
# panel_tilt_angle    0
# latitude            0
# longitude           0
# output_category     0
# dtype: int64

# %%
dataset.cov()
# Out:
#                   Efficiency  Degradation     Power(W)  solar_irradiance  \
# Efficiency          7.908589    -0.012398     0.676351         -6.011130
# Degradation        -0.012398     0.066874     0.371005          1.365072
# Power(W)            0.676351     0.371005  3241.549706        363.526312
# solar_irradiance   -6.011130     1.365072   363.526312      54661.207786
# temperature        -0.653943    -0.003638    -5.801608        125.722165
# humidity           -0.494602     0.123521   -21.793168        130.663112
# wind_speed          0.055031    -0.053332     2.621224         -4.013256
# cloud_cover        -1.171037     0.353458    67.137926       -230.545064
# panel_age          -0.338596     0.086606     0.668024         -2.801010
# panel_tilt_angle    0.831312     0.081540   -12.346066         97.875191
# latitude            0.676953     0.043670   -21.552707         79.664020
# longitude          -3.053789     0.085750   -19.782606       -149.126083
#
# ...

# %%
dataset.corr()
# Out:
#                   Efficiency  Degradation  Power(W)  solar_irradiance  \
# Efficiency          1.000000    -0.017047  0.004224         -0.009143
# Degradation        -0.017047     1.000000  0.025199          0.022578
# Power(W)            0.004224     0.025199  1.000000          0.027310
# solar_irradiance   -0.009143     0.022578  0.027310          1.000000
# temperature        -0.027003    -0.001634 -0.011833          0.062444
# humidity           -0.007508     0.020391 -0.016341          0.023858
# wind_speed          0.004535    -0.047793  0.010669         -0.003978
# cloud_cover        -0.014964     0.049118  0.042376         -0.035436
# panel_age          -0.016812     0.046764  0.001638         -0.001673
# panel_tilt_angle    0.020496     0.021863 -0.015035          0.029027
# latitude            0.033453     0.023469 -0.052609          0.047354
# longitude          -0.061916     0.018907 -0.019812         -0.036369
#
# ...

# %%
quan=[]
qual=[]
for ColumnName in dataset.columns:

    if (dataset[ColumnName].dtype=='O'):
        qual.append(ColumnName)
    else:
        quan.append(ColumnName)

# %%
quan
# Out:
# ['Efficiency',
#  'Degradation',
#  'Power(W)',
#  'solar_irradiance',
#  'temperature',
#  'humidity',
#  'wind_speed',
#  'cloud_cover',
#  'panel_age',
#  'panel_tilt_angle',
#  'latitude',
#  'longitude']

# %%
qual
# Out:
# ['Panel', 'output_category']

# %% [markdown]
# Independant Sample- Unpaired T Test

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
A=dataset[dataset['Panel']=='Panel_A']['longitude']
B=dataset[dataset['Panel']=='Panel_B']['longitude']
ttest_ind(A,B)
# Out:
# Ttest_indResult(statistic=-0.3302962900118921, pvalue=0.7412826885100777)

# %%
other=dataset[dataset['Panel']=='Panel_B']['humidity']
other
# Out:
# 3      60.115497
# 10     11.282206
# 11     48.090953
# 13     71.421745
# 18     36.429379
#          ...
# 987    58.676080
# 994    74.491360
# 995    21.291239
# 996    45.690515
# 998    84.590728
# Name: humidity, Length: 331, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
A=dataset[dataset['Panel']=='Panel_A']['Power(W)']
B=dataset[dataset['Panel']=='Panel_B']['Power(W)']
ttest_ind(A,B)
# Out:
# Ttest_indResult(statistic=-0.005120150869158192, pvalue=0.9959163019255184)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
A=dataset[dataset['Panel']=='Panel_A']['solar_irradiance']
C=dataset[dataset['Panel']=='Panel_C']['solar_irradiance']
ttest_ind(A,C)
# Out:
# Ttest_indResult(statistic=0.058093784447820436, pvalue=0.9536913246565505)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
A=dataset[dataset['Panel']=='Panel_A']['Efficiency']
C=dataset[dataset['Panel']=='Panel_C']['Efficiency']
ttest_ind(A,C)
# Out:
# Ttest_indResult(statistic=0.42249423329402447, pvalue=0.6728004690091844)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
A=dataset[dataset['Panel']=='Panel_A']['Degradation']
C=dataset[dataset['Panel']=='Panel_C']['Degradation']
ttest_ind(A,C)
# Out:
# Ttest_indResult(statistic=2.7343252728915988, pvalue=0.006416758561106699)

# %% [markdown]
# # Independent Samples -Unpaired T-Test

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
other=dataset[dataset['Panel']=='Panel_A']['Efficiency']
central=dataset[dataset['Panel']=='Panel_A']['Degradation']
ttest_ind(other,central)
# Out:
# Ttest_indResult(statistic=91.51061241399846, pvalue=0.0)

# %% [markdown]
# The P value is 0
# T Score value tells that the group are different

# %% [markdown]
# The p-value of 0 supports the alternative  hypothesis (H1).

# %%
tem=dataset[dataset['Panel']=='Panel_A']['temperature']
tem
# Out:
# 2      31.027154
# 6      20.729207
# 9      29.936895
# 15     18.073802
# 17     10.479424
#          ...
# 986    10.769991
# 991    23.985668
# 992    11.895862
# 993    11.514416
# 999    39.039397
# Name: temperature, Length: 320, dtype: float64

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
com=dataset[dataset['Panel']=='Panel_C']['Efficiency']
com1=dataset[dataset['Panel']=='Panel_C']['Degradation']
ttest_rel(com,com1)
# Out:
# Ttest_relResult(statistic=95.3924228870867, pvalue=1.4684994981121151e-251)

# %% [markdown]
# pvalue=1.4684994981121151e-251  supports alternative hypothesis

# %% [markdown]
# # ANAVO=Analysis Of Variance

# %% [markdown]
# # One Way Classification :

# %%
import scipy.stats as stats
stats.f_oneway(dataset["Efficiency"],dataset["Degradation"])
# Out:
# F_onewayResult(statistic=26025.13886159668, pvalue=0.0)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["Efficiency"],dataset["Power(W)"])
# Out:
# F_onewayResult(statistic=24728.519904179884, pvalue=0.0)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["Efficiency"],dataset["solar_irradiance"])
# Out:
# F_onewayResult(statistic=6157.796237441221, pvalue=0.0)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["temperature"],dataset["solar_irradiance"])
# Out:
# F_onewayResult(statistic=5941.68633120225, pvalue=0.0)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["wind_speed"],dataset["cloud_cover"])
# Out:
# F_onewayResult(statistic=2375.961471795271, pvalue=0.0)

# %% [markdown]
# # ANOVA: Two Way Classification:

# %%
y = dataset['output_category']
from sklearn.preprocessing import LabelEncoder, StandardScaler
label_encoder = LabelEncoder()
dep = label_encoder.fit_transform(y)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
anova_two=ols('dep ~ Efficiency + Degradation + Efficiency*Degradation',data=dataset).fit()
Two=sm.stats.anova_lm(anova_two,type=2)
Two
# Out:
#                            df      sum_sq   mean_sq         F    PR(>F)
# Efficiency                1.0    0.179032  0.179032  0.435139  0.509631
# Degradation               1.0    0.246400  0.246400  0.598879  0.439190
# Efficiency:Degradation    1.0    0.560055  0.560055  1.361223  0.243605
# Residual                996.0  409.789513  0.411435       NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
anova_two=ols('dep ~ Efficiency + Degradation +solar_irradiance+ Efficiency*Degradation*solar_irradiance',data=dataset).fit()
Two=sm.stats.anova_lm(anova_two,type=2)
Two
# Out:
#                                             df      sum_sq   mean_sq  \
# Efficiency                                 1.0    0.179032  0.179032
# Degradation                                1.0    0.246400  0.246400
# solar_irradiance                           1.0    0.494522  0.494522
# Efficiency:Degradation                     1.0    0.554031  0.554031
# Efficiency:solar_irradiance                1.0    0.551736  0.551736
# Degradation:solar_irradiance               1.0    0.199351  0.199351
# Efficiency:Degradation:solar_irradiance    1.0    0.162268  0.162268
# Residual                                 992.0  408.387662  0.411681
#
#                                                 F    PR(>F)
# Efficiency                               0.434879  0.509758
# Degradation                              0.598521  0.439327
# solar_irradiance                         1.201225  0.273343
# Efficiency:Degradation                   1.345777  0.246297
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
anova_two=ols('dep ~ temperature + humidity +wind_speed+cloud_cover+temperature*humidity*solar_irradiance*cloud_cover',data=dataset).fit()
Two=sm.stats.anova_lm(anova_two,type=2)
Two
# Out:
#                                                       df      sum_sq  \
# temperature                                          1.0   35.603031
# humidity                                             1.0    1.137197
# wind_speed                                           1.0    2.249244
# cloud_cover                                          1.0   52.737646
# temperature:humidity                                 1.0    0.083054
# solar_irradiance                                     1.0    1.818427
# temperature:solar_irradiance                         1.0    1.488893
# humidity:solar_irradiance                            1.0    0.000196
# temperature:humidity:solar_irradiance                1.0    0.923333
# temperature:cloud_cover                              1.0    9.786558
# humidity:cloud_cover                                 1.0    0.146003
# temperature:humidity:cloud_cover                     1.0    0.314804
# solar_irradiance:cloud_cover                         1.0   43.384223
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
anova_two=ols('dep ~ panel_age + panel_tilt_angle +latitude+longitude+panel_age*panel_tilt_angle*latitude*longitude',data=dataset).fit()
Two=sm.stats.anova_lm(anova_two,type=2)
Two
# Out:
#                                                   df      sum_sq   mean_sq  \
# panel_age                                        1.0    0.321122  0.321122
# panel_tilt_angle                                 1.0    0.074676  0.074676
# latitude                                         1.0    0.223394  0.223394
# longitude                                        1.0    0.834234  0.834234
# panel_age:panel_tilt_angle                       1.0    0.080479  0.080479
# panel_age:latitude                               1.0    0.290800  0.290800
# panel_tilt_angle:latitude                        1.0    0.000914  0.000914
# panel_age:panel_tilt_angle:latitude              1.0    0.425405  0.425405
# panel_age:longitude                              1.0    0.079216  0.079216
# panel_tilt_angle:longitude                       1.0    0.716081  0.716081
# panel_age:panel_tilt_angle:longitude             1.0    0.003347  0.003347
# ...
