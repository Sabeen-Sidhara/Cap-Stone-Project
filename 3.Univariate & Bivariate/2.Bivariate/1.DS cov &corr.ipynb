# %%
import pandas as pd

# %%
dataset=pd.read_csv("solar_panel_classification_data.csv")
dataset
# Out:
#        Panel  Efficiency  Degradation  Power(W)  solar_irradiance  \
# 0    Panel_C       10.50         0.26       276        234.582148
# 1    Panel_C       13.35         0.95       248        701.541503
# 2    Panel_A       11.59         0.67       248        800.323062
# 3    Panel_B       14.53         0.48       384        264.976616
# 4    Panel_C       12.29         0.22       299        314.577546
# ..       ...         ...          ...       ...               ...
# 995  Panel_B       18.10         0.15       302        714.936187
# 996  Panel_B       12.30         0.65       226        736.401113
# 997  Panel_C       10.12         0.56       291        863.499489
# 998  Panel_B       13.77         0.28       315        738.160525
# 999  Panel_A       15.27         0.38       210        316.168286
#
#      temperature   humidity  wind_speed  cloud_cover  panel_age  \
# 0      27.409992  34.203594   12.909419    47.135301          8
# ...

# %%
dataset.isnull().sum()
# Out:
# Panel               0
# Efficiency          0
# Degradation         0
# Power(W)            0
# solar_irradiance    0
# temperature         0
# humidity            0
# wind_speed          0
# cloud_cover         0
# panel_age           0
# panel_tilt_angle    0
# latitude            0
# longitude           0
# output_category     0
# dtype: int64

# %% [markdown]
# # Covariance:

# %%
dataset.cov()
# Out:
#                   Efficiency  Degradation     Power(W)  solar_irradiance  \
# Efficiency          7.908589    -0.012398     0.676351         -6.011130
# Degradation        -0.012398     0.066874     0.371005          1.365072
# Power(W)            0.676351     0.371005  3241.549706        363.526312
# solar_irradiance   -6.011130     1.365072   363.526312      54661.207786
# temperature        -0.653943    -0.003638    -5.801608        125.722165
# humidity           -0.494602     0.123521   -21.793168        130.663112
# wind_speed          0.055031    -0.053332     2.621224         -4.013256
# cloud_cover        -1.171037     0.353458    67.137926       -230.545064
# panel_age          -0.338596     0.086606     0.668024         -2.801010
# panel_tilt_angle    0.831312     0.081540   -12.346066         97.875191
# latitude            0.676953     0.043670   -21.552707         79.664020
# longitude          -3.053789     0.085750   -19.782606       -149.126083
#
# ...

# %% [markdown]
# # Correlation:

# %%
dataset.corr()
# Out:
#                   Efficiency  Degradation  Power(W)  solar_irradiance  \
# Efficiency          1.000000    -0.017047  0.004224         -0.009143
# Degradation        -0.017047     1.000000  0.025199          0.022578
# Power(W)            0.004224     0.025199  1.000000          0.027310
# solar_irradiance   -0.009143     0.022578  0.027310          1.000000
# temperature        -0.027003    -0.001634 -0.011833          0.062444
# humidity           -0.007508     0.020391 -0.016341          0.023858
# wind_speed          0.004535    -0.047793  0.010669         -0.003978
# cloud_cover        -0.014964     0.049118  0.042376         -0.035436
# panel_age          -0.016812     0.046764  0.001638         -0.001673
# panel_tilt_angle    0.020496     0.021863 -0.015035          0.029027
# latitude            0.033453     0.023469 -0.052609          0.047354
# longitude          -0.061916     0.018907 -0.019812         -0.036369
#
# ...
