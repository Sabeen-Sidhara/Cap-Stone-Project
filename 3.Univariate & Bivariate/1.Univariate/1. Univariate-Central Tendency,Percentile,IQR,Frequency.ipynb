# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("solar_panel_classification_data.csv")

# %%
dataset
# Out:
#        Panel  Efficiency  Degradation  Power(W)  solar_irradiance  \
# 0    Panel_C       10.50         0.26       276        234.582148
# 1    Panel_C       13.35         0.95       248        701.541503
# 2    Panel_A       11.59         0.67       248        800.323062
# 3    Panel_B       14.53         0.48       384        264.976616
# 4    Panel_C       12.29         0.22       299        314.577546
# ..       ...         ...          ...       ...               ...
# 995  Panel_B       18.10         0.15       302        714.936187
# 996  Panel_B       12.30         0.65       226        736.401113
# 997  Panel_C       10.12         0.56       291        863.499489
# 998  Panel_B       13.77         0.28       315        738.160525
# 999  Panel_A       15.27         0.38       210        316.168286
#
#      temperature   humidity  wind_speed  cloud_cover  panel_age  \
# 0      27.409992  34.203594   12.909419    47.135301          8
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
# Panel               1000 non-null object
# Efficiency          1000 non-null float64
# Degradation         1000 non-null float64
# Power(W)            1000 non-null int64
# solar_irradiance    1000 non-null float64
# temperature         1000 non-null float64
# humidity            1000 non-null float64
# wind_speed          1000 non-null float64
# cloud_cover         1000 non-null float64
# panel_age           1000 non-null int64
# panel_tilt_angle    1000 non-null int64
# latitude            1000 non-null float64
# longitude           1000 non-null float64
# output_category     1000 non-null object
# dtypes: float64(9), int64(3), object(2)
# memory usage: 109.5+ KB

# %%
dataset.columns
# Out:
# Index(['Panel', 'Efficiency', 'Degradation', 'Power(W)', 'solar_irradiance',
#        'temperature', 'humidity', 'wind_speed', 'cloud_cover', 'panel_age',
#        'panel_tilt_angle', 'latitude', 'longitude', 'output_category'],
#       dtype='object')

# %%
dir(dataset)
# Out:
# ['Degradation',
#  'Efficiency',
#  'Panel',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
dataset.dtypes
# Out:
# Panel                object
# Efficiency          float64
# Degradation         float64
# Power(W)              int64
# solar_irradiance    float64
# temperature         float64
# humidity            float64
# wind_speed          float64
# cloud_cover         float64
# panel_age             int64
# panel_tilt_angle      int64
# latitude            float64
# longitude           float64
# output_category      object
# dtype: object

# %%
dataset["Power(W)"].dtypes
# Out:
# dtype('int64')

# %%
for ColumnName in dataset.columns:
    print(ColumnName)
# Out:
# Panel
# Efficiency
# Degradation
# Power(W)
# solar_irradiance
# temperature
# humidity
# wind_speed
# cloud_cover
# panel_age
# panel_tilt_angle
# latitude
# longitude
# output_category

# %%
if (dataset['Power(W)'].dtype=='O'):
    print('qual')
else:
    print('quan')
# Out:
# quan

# %%
quan=[]
qual=[]
for ColumnName in dataset.columns:
    print(ColumnName)
    if (dataset['solar_irradiance'].dtype=='O'):
        print('qual')
    else:
        print('quan')
# Out:
# Panel
# quan
# Efficiency
# quan
# Degradation
# quan
# Power(W)
# quan
# solar_irradiance
# quan
# temperature
# quan
# humidity
# quan
# wind_speed
# quan
# cloud_cover
# quan
# panel_age
# quan
# panel_tilt_angle
# quan
# latitude
# quan
# longitude
# quan
# output_category
# quan

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for ColumnName in dataset.columns:

        if (dataset[ColumnName].dtype=='O'):
            qual.append(ColumnName)
        else:
             quan.append(ColumnName)
    return quan,qual

# %%
quan,qual=quanqual(dataset)

# %% [markdown]
# Central Tendency

# %%
dataset['longitude'].mean()
# Out:
# -94.25792599335

# %%
dataset['longitude'].median()
# Out:
# -92.93763275

# %%
dataset['longitude'].mode()[0]
# Out:
# -124.9936041

# %%
dataset.describe()
# Out:
#         Efficiency  Degradation     Power(W)  solar_irradiance  temperature  \
# count  1000.000000  1000.000000  1000.000000       1000.000000  1000.000000
# mean     14.969670     0.562640   298.438000        595.177632    24.896671
# std       2.812221     0.258599    56.934609        233.797365     8.611503
# min      10.010000     0.100000   200.000000        200.404190    10.003139
# 25%      12.670000     0.330000   250.000000        390.303447    17.128663
# 50%      15.135000     0.560000   295.000000        600.164033    25.028169
# 75%      17.232500     0.780000   348.000000        791.247724    32.088025
# max      19.980000     1.000000   399.000000        996.551843    39.899973
#
#           humidity   wind_speed  cloud_cover    panel_age  panel_tilt_angle  \
# count  1000.000000  1000.000000  1000.000000  1000.000000       1000.000000
# mean     50.467837     7.611624    51.017987    12.038000         29.940000
# ...

# %%
descriptive=pd.DataFrame(index=['Mean','Median','Mode'],columns=quan)

# %%
descriptive
# Out:
#        Efficiency Degradation Power(W) solar_irradiance temperature humidity  \
# Mean          NaN         NaN      NaN              NaN         NaN      NaN
# Median        NaN         NaN      NaN              NaN         NaN      NaN
# Mode          NaN         NaN      NaN              NaN         NaN      NaN
#
#        wind_speed cloud_cover panel_age panel_tilt_angle latitude longitude
# Mean          NaN         NaN       NaN              NaN      NaN       NaN
# Median        NaN         NaN       NaN              NaN      NaN       NaN
# Mode          NaN         NaN       NaN              NaN      NaN       NaN

# %%
descriptive['longitude']['Median']=0

# %%
descriptive=pd.DataFrame(index=['Mean','Median','Mode'],columns=quan)
for ColumnName in quan:
    descriptive[ColumnName]['Mean']=dataset[ColumnName].mean()
    descriptive[ColumnName]['Median']=dataset[ColumnName].median()
    descriptive[ColumnName]['Mode']=dataset[ColumnName].mode()[0]

# %%
descriptive
# Out:
#        Efficiency Degradation Power(W) solar_irradiance temperature humidity  \
# Mean      14.9697     0.56264  298.438          595.178     24.8967  50.4678
# Median     15.135        0.56      295          600.164     25.0282  51.1235
# Mode        13.08        0.23      218          200.404     10.0031  10.0437
#
#        wind_speed cloud_cover panel_age panel_tilt_angle latitude longitude
# Mean      7.61162      51.018    12.038            29.94  37.3771  -94.2579
# Median     7.6909     50.9363        12               30  37.2614  -92.9376
# Mode    0.0821637     0.13549        14               10  25.0583  -124.994

# %%
import numpy as np

# %%
np.percentile(dataset['longitude'],99)
# Out:
# -65.4740055077

# %%
np.percentile(dataset['Efficiency'],100)
# Out:
# 19.98

# %%
descriptive=pd.DataFrame(index=['q1:25','q2:50','q3:75','99%','q4:100'],columns=quan)
for ColumnName in quan:
    descriptive[ColumnName]['q1:25']=dataset.describe()[ColumnName]['25%']
    descriptive[ColumnName]['q2:50']=dataset.describe()[ColumnName]['50%']
    descriptive[ColumnName]['q3:75']=dataset.describe()[ColumnName]['75%']
    descriptive[ColumnName]['99%']=np.percentile(dataset[ColumnName],99)
    descriptive[ColumnName]['q4:100']=dataset.describe()[ColumnName]['max']

# %%
descriptive
# Out:
#        Efficiency Degradation Power(W) solar_irradiance temperature humidity  \
# q1:25       12.67        0.33      250          390.303     17.1287  30.2236
# q2:50      15.135        0.56      295          600.164     25.0282  51.1235
# q3:75     17.2325        0.78      348          791.248      32.088  70.7696
# 99%         19.89        0.99      397          984.042     39.5749  89.2366
# q4:100      19.98           1      399          996.552        39.9  89.8757
#
#        wind_speed cloud_cover panel_age panel_tilt_angle latitude longitude
# q1:25     3.87703     27.6951         6               20  31.3821  -109.559
# q2:50      7.6909     50.9363        12               30  37.2614  -92.9376
# q3:75     11.4897     75.1159        18               40  43.4429   -79.881
# 99%        14.876     98.6133        24               50  49.7533   -65.474
# q4:100    14.9459     99.9285        24               50  49.9765  -65.0772

# %%
descriptive
# Out:
#        Efficiency Degradation Power(W) solar_irradiance temperature humidity  \
# q1:25       12.67        0.33      250          390.303     17.1287  30.2236
# q2:50      15.135        0.56      295          600.164     25.0282  51.1235
# q3:75     17.2325        0.78      348          791.248      32.088  70.7696
# 99%         19.89        0.99      397          984.042     39.5749  89.2366
# q4:100      19.98           1      399          996.552        39.9  89.8757
#
#        wind_speed cloud_cover panel_age panel_tilt_angle latitude longitude
# q1:25     3.87703     27.6951         6               20  31.3821  -109.559
# q2:50      7.6909     50.9363        12               30  37.2614  -92.9376
# q3:75     11.4897     75.1159        18               40  43.4429   -79.881
# 99%        14.876     98.6133        24               50  49.7533   -65.474
# q4:100    14.9459     99.9285        24               50  49.9765  -65.0772

# %% [markdown]
# Frequency

# %%
def FreqTable(ColumnName, dataset):
        FreqTable = pd.DataFrame(columns=["Unique_Values", "Frequency", "Relative_Frequency", "cumsum"])
        FreqTable["Unique_Values"] = dataset[ColumnName].value_counts().index
        FreqTable["Frequency"] = dataset[ColumnName].value_counts().values
        FreqTable["Relative_Frequency"] = FreqTable["Frequency"] / len(dataset)
        FreqTable[ "cumsum"] = FreqTable["Relative_Frequency"].cumsum()
        return FreqTable

# %%
FreqTable("Efficiency", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0            13.08          6               0.006   0.006
# 1            16.27          5               0.005   0.011
# 2            10.82          5               0.005   0.016
# 3            17.16          5               0.005   0.021
# 4            15.27          5               0.005   0.026
# ..             ...        ...                 ...     ...
# 623          14.29          1               0.001   0.996
# 624          16.40          1               0.001   0.997
# 625          18.60          1               0.001   0.998
# 626          17.08          1               0.001   0.999
# 627          18.95          1               0.001   1.000
#
# [628 rows x 4 columns]

# %%
FreqTable("Degradation", dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  cumsum
# 0            0.28         20               0.020   0.020
# 1            0.23         20               0.020   0.040
# 2            0.88         19               0.019   0.059
# 3            0.98         17               0.017   0.076
# 4            0.92         17               0.017   0.093
# ..            ...        ...                 ...     ...
# 86           0.80          6               0.006   0.983
# 87           0.76          5               0.005   0.988
# 88           0.14          5               0.005   0.993
# 89           0.24          4               0.004   0.997
# 90           0.10          3               0.003   1.000
#
# [91 rows x 4 columns]

# %%
FreqTable("Power(W)", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0              218         12               0.012   0.012
# 1              291         12               0.012   0.024
# 2              257         11               0.011   0.035
# 3              217         11               0.011   0.046
# 4              352         10               0.010   0.056
# ..             ...        ...                 ...     ...
# 193            231          1               0.001   0.996
# 194            380          1               0.001   0.997
# 195            301          1               0.001   0.998
# 196            386          1               0.001   0.999
# 197            399          1               0.001   1.000
#
# [198 rows x 4 columns]

# %%
FreqTable("solar_irradiance", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0       950.812268          1               0.001   0.001
# 1       369.826359          1               0.001   0.002
# 2       678.886293          1               0.001   0.003
# 3       860.834051          1               0.001   0.004
# 4       602.111551          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995     939.921115          1               0.001   0.996
# 996     912.669063          1               0.001   0.997
# 997     582.546553          1               0.001   0.998
# 998     663.125314          1               0.001   0.999
# 999     741.636013          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("temperature", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0        26.734922          1               0.001   0.001
# 1        31.009678          1               0.001   0.002
# 2        32.659704          1               0.001   0.003
# 3        30.470217          1               0.001   0.004
# 4        20.853316          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995      29.942795          1               0.001   0.996
# 996      30.333321          1               0.001   0.997
# 997      22.989973          1               0.001   0.998
# 998      34.932448          1               0.001   0.999
# 999      35.005192          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("humidity", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0        28.782419          1               0.001   0.001
# 1        13.452174          1               0.001   0.002
# 2        81.270108          1               0.001   0.003
# 3        46.406816          1               0.001   0.004
# 4        17.773745          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995      52.832370          1               0.001   0.996
# 996      70.662961          1               0.001   0.997
# 997      50.996580          1               0.001   0.998
# 998      54.354541          1               0.001   0.999
# 999      56.434381          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("wind_speed", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0         9.666572          1               0.001   0.001
# 1         2.948005          1               0.001   0.002
# 2        13.103587          1               0.001   0.003
# 3        14.116266          1               0.001   0.004
# 4         5.429368          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995       9.945316          1               0.001   0.996
# 996       7.220932          1               0.001   0.997
# 997       9.328914          1               0.001   0.998
# 998      12.243678          1               0.001   0.999
# 999       4.788790          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("cloud_cover", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0        75.531284          1               0.001   0.001
# 1        74.667334          1               0.001   0.002
# 2        24.495524          1               0.001   0.003
# 3        76.976063          1               0.001   0.004
# 4        58.909494          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995      61.346072          1               0.001   0.996
# 996      10.975000          1               0.001   0.997
# 997      85.671223          1               0.001   0.998
# 998      30.122929          1               0.001   0.999
# 999      72.264256          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("panel_age", dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  cumsum
# 0              14         53               0.053   0.053
# 1               8         51               0.051   0.104
# 2              12         48               0.048   0.152
# 3              21         48               0.048   0.200
# 4               2         47               0.047   0.247
# 5               3         45               0.045   0.292
# 6              15         44               0.044   0.336
# 7              24         42               0.042   0.378
# 8              17         42               0.042   0.420
# 9               0         41               0.041   0.461
# 10             18         41               0.041   0.502
# 11             20         41               0.041   0.543
# 12              9         40               0.040   0.583
# 13              4         38               0.038   0.621
# 14             13         38               0.038   0.659
# ...

# %%
FreqTable("panel_tilt_angle", dataset)
# Out:
#    Unique_Values  Frequency  Relative_Frequency  cumsum
# 0             10        216               0.216   0.216
# 1             50        208               0.208   0.424
# 2             40        196               0.196   0.620
# 3             30        194               0.194   0.814
# 4             20        186               0.186   1.000

# %%
FreqTable("latitude", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0        28.156473          1               0.001   0.001
# 1        48.295190          1               0.001   0.002
# 2        46.837884          1               0.001   0.003
# 3        46.752057          1               0.001   0.004
# 4        39.709615          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995      42.887568          1               0.001   0.996
# 996      49.592532          1               0.001   0.997
# 997      32.745694          1               0.001   0.998
# 998      42.620129          1               0.001   0.999
# 999      46.207967          1               0.001   1.000
#
# [1000 rows x 4 columns]

# %%
FreqTable("longitude", dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  cumsum
# 0      -107.071670          1               0.001   0.001
# 1      -114.473219          1               0.001   0.002
# 2      -104.191595          1               0.001   0.003
# 3      -100.471442          1               0.001   0.004
# 4       -95.583195          1               0.001   0.005
# ..             ...        ...                 ...     ...
# 995     -90.843223          1               0.001   0.996
# 996    -106.205107          1               0.001   0.997
# 997     -76.734490          1               0.001   0.998
# 998    -123.495829          1               0.001   0.999
# 999     -93.629622          1               0.001   1.000
#
# [1000 rows x 4 columns]
